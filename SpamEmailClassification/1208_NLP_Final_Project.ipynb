# %% [markdown]
# # NLP Final Project - Email Spam Corpera

# %% [markdown]
# By: Brandon Croarkin, Michelle Mak, and T.S. Yeap

# %%
# open python and nltk packages needed for processing
import os
import sys
import random
import re
import nltk
from nltk.corpus import stopwords
from nltk.corpus import sentence_polarity
from nltk.collocations import *
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
#os.chdir(r'C:\Users\brcro\OneDrive\Documents\Syracuse\IST 664 - Natural Language Processing\Final Project\FinalProjectData\EmailSpamCorpora\corpus')
os.chdir(r'/Users/michelle.mak/Desktop/Syracuse/IST_664_NLP/Final_Project/EmailSpamCorpora/corpus')

# %%
os.listdir()
# Out:
# ['spam', '.DS_Store', 'ham']

# %% [markdown]
# # Creating Functions

# %%
# define features (keywords) of a document for a BOW/unigram baseline
# each feature is 'contains(keyword)' and is true or false depending
# on whether that keyword is in the document
def document_features(document, word_features):
    document_words = set(document)
    features = {}
    for word in word_features:
        features['V_{}'.format(word)] = (word in document_words)
    return features

# %%
# function that takes a word and returns true if it consists only
# of non-alphabetic characters  (assumes import re)
def alpha_filter(w):
    # pattern to match word of non-alphabetical characters
    pattern = re.compile('^[^a-z]+$')
    if (pattern.match(w)):
        return True
    else:
        return False

# %%
# define features that include words as before 
# add the most frequent significant bigrams
# this function takes the list of words in a document as an argument and returns a feature dictionary
# it depends on the variables word_features and bigram_features
def bigram_document_features(document, word_features, bigram_features):
    document_words = set(document)
    document_bigrams = nltk.bigrams(document)
    features = {}
    for word in word_features:
        features['V_{}'.format(word)] = (word in document_words)
    for bigram in bigram_features:
        features['B_{}_{}'.format(bigram[0], bigram[1])] = (bigram in document_bigrams)    
    return features

# %%
# this function takes a document list of words and returns a feature dictionary
# it runs the default pos tagger (the Stanford tagger) on the document
#   and counts 4 types of pos tags to use as features
def POS_features(document, word_features):
    document_words = set(document)
    tagged_words = nltk.pos_tag(document)
    features = {}
    for word in word_features:
        features['contains({})'.format(word)] = (word in document_words)
    numNoun = 0
    numVerb = 0
    numAdj = 0
    numAdverb = 0
    for (word, tag) in tagged_words:
        if tag.startswith('N'): numNoun += 1
        if tag.startswith('V'): numVerb += 1
        if tag.startswith('J'): numAdj += 1
        if tag.startswith('R'): numAdverb += 1
    features['nouns'] = numNoun
    features['verbs'] = numVerb
    features['adjectives'] = numAdj
    features['adverbs'] = numAdverb
    return features

# %%
## cross-validation ##
# this function takes the number of folds, the feature sets
# it iterates over the folds, using different sections for training and testing in turn
#   it prints the precision, recall and F score for each fold
#.  (it does not compute the average over the folds)
def cross_validation_PRF(num_folds, featuresets):
    subset_size = int(len(featuresets)/num_folds)
    print('Each fold size:', subset_size)
    #accuracy_list = []
    # iterate over the folds
    for i in range(num_folds):
        test_this_round = featuresets[(i*subset_size):][:subset_size]
        train_this_round = featuresets[:(i*subset_size)] + featuresets[((i+1)*subset_size):]
        # train using train_this_round
        classifier = nltk.NaiveBayesClassifier.train(train_this_round)
        # evaluate against test_this_round to produce the gold and predicted labels
        goldlist = []
        predictedlist = []
        for (features, label) in test_this_round:
            goldlist.append(label)
            predictedlist.append(classifier.classify(features))

        # call the function with our data
        eval_measures(goldlist, predictedlist)
    # this version doesn't save measures and compute averages

# %%
# this function returns a dictionary where you can look up words and get back 
#     the four items of subjectivity information described above
def readSubjectivity(path):
    flexicon = open(path, 'r')
    # initialize an empty dictionary
    sldict = { }
    for line in flexicon:
        fields = line.split()   # default is to split on whitespace
        # split each field on the '=' and keep the second part as the value
        strength = fields[0].split("=")[1]
        word = fields[2].split("=")[1]
        posTag = fields[3].split("=")[1]
        stemmed = fields[4].split("=")[1]
        polarity = fields[5].split("=")[1]
        if (stemmed == 'y'):
            isStemmed = True
        else:
            isStemmed = False
        # put a dictionary entry with the word as the keyword
        #     and a list of the other values
        sldict[word] = [strength, posTag, isStemmed, polarity]
    return sldict

# %%
# define features that include word counts of subjectivity words
# negative feature will have number of weakly negative words +
#    2 * number of strongly negative words
# positive feature has similar definition
#    not counting neutral words

def SL_features(document, word_features, SL):
    document_words = set(document)
    features = {}
    for word in word_features:
        features['V_{}'.format(word)] = (word in document_words)
    # count variables for the 4 classes of subjectivity
    weakPos = 0
    strongPos = 0
    weakNeg = 0
    strongNeg = 0
    for word in document_words:
        if word in SL:
            strength, posTag, isStemmed, polarity = SL[word]
            if strength == 'weaksubj' and polarity == 'positive':    
                weakPos += 1
            if strength == 'strongsubj' and polarity == 'positive':  
                strongPos += 1
            if strength == 'weaksubj' and polarity == 'negative':    
                weakNeg += 1
            if strength == 'strongsubj' and polarity == 'negative':  
                strongNeg += 1
            features['positivecount'] = weakPos + (2 * strongPos)
            features['negativecount'] = weakNeg + (2 * strongNeg)      
    return features

# %%
def eval_measures(gold, predicted):
    # get a list of labels
    labels = list(set(gold))
    # these lists have values for each label
    recall_list = []
    precision_list = []
    F1_list = []
    for lab in labels:
        # for each label, compare gold and predicted lists and compute values
        TP = FP = FN = TN = 0
        for i, val in enumerate(gold):
            if val == lab and predicted[i] == lab:  TP += 1
            if val == lab and predicted[i] != lab:  FN += 1
            if val != lab and predicted[i] == lab:  FP += 1
            if val != lab and predicted[i] != lab:  TN += 1
        # use these to compute recall, precision, F1
        recall = TP / (TP + FP)
        precision = TP / (TP + FN)
        recall_list.append(recall)
        precision_list.append(precision)
        F1_list.append( 2 * (recall * precision) / (recall + precision))

    # the evaluation measures in a table with one row per label
    print('Label\tPrecision\tRecall\t\tF1')
    # print measures for each label
    for i, lab in enumerate(labels):
        print(lab, '\t', "{:10.3f}".format(precision_list[i]), \
          "{:10.3f}".format(recall_list[i]), "{:10.3f}".format(F1_list[i]))

# %%
# this function takes the number of folds, the feature sets
# it iterates over the folds, using different sections for training and testing in turn
#   it prints the accuracy for each fold and the average accuracy at the end
def cross_validation_accuracy(num_folds, featuresets):
    subset_size = int(len(featuresets)/num_folds)
    print('Each fold size:', subset_size)
    accuracy_list = []
    # iterate over the folds
    for i in range(num_folds):
        test_this_round = featuresets[(i*subset_size):][:subset_size]
        train_this_round = featuresets[:(i*subset_size)] + featuresets[((i+1)*subset_size):]
        # train using train_this_round
        classifier = nltk.NaiveBayesClassifier.train(train_this_round)
        # evaluate against test_this_round and save accuracy
        accuracy_this_round = nltk.classify.accuracy(classifier, test_this_round)
        print (i, accuracy_this_round)
        accuracy_list.append(accuracy_this_round)
    # find mean accuracy over all rounds
    print ('mean accuracy', sum(accuracy_list) / num_folds)

# %%
# One strategy with negation words is to negate the word following the negation word
#   other strategies negate all words up to the next punctuation
# Strategy is to go through the document words in order adding the word features,
#   but if the word follows a negation words, change the feature to negated word
# Start the feature set with all 2000 word features and 2000 Not word features set to false

def NOT_features(document, word_features, negationwords):    
    features = {}
    for word in word_features:
        features['V_{}'.format(word)] = False
        features['V_NOT{}'.format(word)] = False
    # go through document words in order
    for i in range(0, len(document)):
        word = document[i]
        if ((i + 1) < len(document)) and ((word in negationwords) or (word.endswith("n't"))):
            i += 1
            features['V_NOT{}'.format(document[i])] = (document[i] in word_features)
        else:
            features['V_{}'.format(word)] = (word in word_features)
    return features

# %%
# Function writeFeatureSets:
# takes featuresets defined in the nltk and convert them to weka input csv file
#    any feature value in the featuresets should not contain ",", "'" or " itself
#    and write the file to the outpath location
#    outpath should include the name of the csv file
def writeFeatureSets(featuresets, outpath):
    # open outpath for writing
    f = open(outpath, 'w')
    # get the feature names from the feature dictionary in the first featureset
    featurenames = featuresets[0][0].keys()
    # create the first line of the file as comma separated feature names
    #    with the word class as the last feature name
    featurenameline = ''
    for featurename in featurenames:
        # replace forbidden characters with text abbreviations
        featurename = featurename.replace(',','CM')
        featurename = featurename.replace("'","DQ")
        featurename = featurename.replace('"','QU')
        featurenameline += featurename + ','
    featurenameline += 'class'
    # write this as the first line in the csv file
    f.write(featurenameline)
    f.write('\n')
    # convert each feature set to a line in the file with comma separated feature values,
    # each feature value is converted to a string
    #   for booleans this is the words true and false
    #   for numbers, this is the string with the number
    for featureset in featuresets:
        featureline = ''
        for key in featurenames:
            featureline += str(featureset[0][key]) + ','
        featureline += featureset[1]
        # write each feature set values to the file
        f.write(featureline)
        f.write('\n')
    f.close()

# %%
# define features (keywords) of a document for a BOW/unigram baseline
# each feature is the TF-IDF score if word is in document
def TFIDF_document_features(document, TF_IDF_dict):
    document_words = set(document)
    features = {}
    for k, v in topkeysnormalized:
        if (k in document_words):
            features['V_{}'.format(k)] = v
        else:
            features['V_{}'.format(k)] = 0
    return features

# %% [markdown]
# ## Creating Word List

# %%
#dirPath = 'C:\\Users\\brcro\\OneDrive\\Documents\\Syracuse\\IST 664 - Natural Language Processing\\Final Project\\FinalProjectData\\EmailSpamCorpora\\corpus'
dirPath = '/Users/michelle.mak/Desktop/Syracuse/IST_664_NLP/Final_Project/EmailSpamCorpora/corpus'
limitStr = 1500

# %%
# convert the limit argument from a string to an int
limit = int(limitStr)
  
# start lists for spam and ham email texts
hamtexts = []
spamtexts = []
os.chdir(dirPath)
# process all files in directory that end in .txt up to the limit
#    assuming that the emails are sufficiently randomized
for file in os.listdir("./spam"):
    if (file.endswith(".txt")) and (len(spamtexts) < limit):
        # open file for reading and read entire file into a string
        f = open("./spam/"+file, 'r', encoding="latin-1")
        spamtexts.append (f.read())
        f.close()
for file in os.listdir("./ham"):
    if (file.endswith(".txt")) and (len(hamtexts) < limit):
        # open file for reading and read entire file into a string
        f = open("./ham/"+file, 'r', encoding="latin-1")
        hamtexts.append (f.read())
        f.close()

# print number emails read
print ("Number of spam files:",len(spamtexts))
print ("Number of ham files:",len(hamtexts))
# Out:
# Number of spam files: 1500
# Number of ham files: 1500

# %%
# create list of mixed spam and ham email documents as (list of words, label)
emaildocs = []
# add all the spam
for spam in spamtexts:
    tokens = nltk.word_tokenize(spam)
    emaildocs.append((tokens, 'spam'))
# add all the regular emails
for ham in hamtexts:
    tokens = nltk.word_tokenize(ham)
    emaildocs.append((tokens, 'ham'))
    
# randomize the list
random.shuffle(emaildocs)
  
# print a few token lists
for email in emaildocs[:1]:
    print(email)
# Out:
# (['Subject', ':', 'all', 'me', '^', 'ds', 'here', 'paliourg', 'user', 'id', ':', '3', 'compendia', 'date', ':', 'tue', ',', '05', 'oct', '2004', '04', ':', '12', ':', '32', '-', '0300', 'mime', '-', 'version', ':', '1', '.', '0', 'content', '-', 'type', ':', 'multipart', '/', 'alternative', ';', 'boundary', '=', '-', '-', '886915596469801750', '-', '-', '-', '-', '886915596469801750', 'content', '-', 'type', ':', 'text', '/', 'plain', ';', 'content', '-', 'transfer', '-', 'encoding', ':', '7', 'bit', 'why', 'pay', 'more', 'when', 'you', 'can', 'enjoy', 'the', 'best', 'and', 'cheapest', 'pills', 'online', '?', 'nearly', '80', 'types', 'to', 'choose', 'which', 'makes', 'ours', 'pharmacy', 'the', 'largest', 'and', 'the', 'best', 'available', '.', 'no', 'appointments', '.', 'no', 'waiting', 'rooms', '.', 'no', 'prior', 'prescription', 'required', '.', 'see', 'why', 'our', 'customers', 're', '-', 'order', 'more', 'than', 'any', 'competitor', '!', 'this', 'is', '1', '-', 'time', 'mai', '|', 'ing', '.', 'no', 'removal', 'are', 're', '-', 'qui', '-', 'red', '-', '-', '-', '-', '886915596469801750', '-', '-'], 'spam')

# %% [markdown]
# ## Data Pre-Processing

# %% [markdown]
# ### All Words

# %%
# get all words from all emails and put into a frequency 
#   note lowercase, but no stemming or stopwords
all_words_list = [word for (sent,cat) in emaildocs for word in sent]
all_words = nltk.FreqDist(all_words_list)

# get the 2000 most frequently appearing keywords in the corpus
word_items = all_words.most_common(2000)
word_features = [word for (word,count) in word_items]
print(word_features[:50])
# Out:
# ['-', '.', ',', '/', ':', 'the', 'to', 'and', 'of', 'a', 'for', 'ect', '?', 'in', 'you', '@', 'this', 'is', 'on', '=', 'i', "'", ')', '(', 'Subject', 'be', '!', 'your', 'hou', 'that', 'enron', 'with', 'we', 'from', 'have', '$', 'will', 's', 'are', 'or', 'as', 'at', ';', 'it', '3', 'not', '2000', 'com', '_', 'if']

# %% [markdown]
# ### Removing Stop Words

# %%
stopwords = nltk.corpus.stopwords.words('english')
len(stopwords)
# Out:
# 179

# %%
newstopwords = [word for word in stopwords if word not in negationwords]
len(newstopwords)
# Out:
# 176

# %%
new_all_words_list = [word for word in all_words_list if word not in newstopwords]
new_all_words = nltk.FreqDist(new_all_words_list)
new_word_items = new_all_words.most_common(2000)
no_stop_word_features = [word for (word,count) in new_word_items]

# %%
print(no_stop_word_features[:30])
# Out:
# ['-', '.', ',', '/', ':', 'ect', '?', '@', '=', "'", ')', '(', 'Subject', '!', 'hou', 'enron', '$', ';', '3', 'not', '2000', 'com', '_', 'please', '``', '1', '2', '00', '%', '|']

# %% [markdown]
# ### Adding Negation Features

# %%
# this list of negation words includes some "approximate negators" like hardly and rarely
negationwords = ['no', 'not', 'never', 'none', 'nowhere', 'nothing', 'noone', 'rather', 'hardly', 'scarcely', 'rarely', 'seldom', 'neither', 'nor']

# %%
new_all_words_list = [word for word in all_words_list if word not in newstopwords]
new_all_words = nltk.FreqDist(new_all_words_list)
new_word_items = new_all_words.most_common(2000)
negation_word_features = [word for (word,count) in new_word_items]
print(negation_word_features[:30])
# Out:
# ['-', '.', ',', '/', ':', 'ect', '?', '@', '=', "'", ')', '(', 'Subject', '!', 'hou', 'enron', '$', ';', '3', 'not', '2000', 'com', '_', 'please', '``', '1', '2', '00', '%', '|']

# %% [markdown]
# ### Removing Non-Alpha Characters

# %%
# Filtered word feature
filtered_words_list = [word for (sent, cat) in emaildocs for word in sent if not alpha_filter(word)]
print(filtered_words_list[:100])
# Out:
# ['Subject', 'all', 'me', 'ds', 'here', 'paliourg', 'user', 'id', 'compendia', 'date', 'tue', 'oct', 'mime', 'version', 'content', 'type', 'multipart', 'alternative', 'boundary', 'content', 'type', 'text', 'plain', 'content', 'transfer', 'encoding', 'bit', 'why', 'pay', 'more', 'when', 'you', 'can', 'enjoy', 'the', 'best', 'and', 'cheapest', 'pills', 'online', 'nearly', 'types', 'to', 'choose', 'which', 'makes', 'ours', 'pharmacy', 'the', 'largest', 'and', 'the', 'best', 'available', 'no', 'appointments', 'no', 'waiting', 'rooms', 'no', 'prior', 'prescription', 'required', 'see', 'why', 'our', 'customers', 're', 'order', 'more', 'than', 'any', 'competitor', 'this', 'is', 'time', 'mai', 'ing', 'no', 'removal', 'are', 're', 'qui', 'red', 'Subject', 'you', 'want', 'a', 'quicker', 'computer', 'spyware', 'stays', 'resident', 'in', 'memory', 'just', 'use', 'this', 'to', 'remove']

# %%
filtered_words = nltk.FreqDist(filtered_words_list)
print(len(filtered_words))
# Out:
# 41262

# %%
filtered_word_items = filtered_words.most_common(1500)
filtered_word_features = [word for (word,count) in filtered_word_items]

# %% [markdown]
# ## Experiments

# %% [markdown]
# ### 1. Unigram Features

# %%
# use document_features function to create unigram feature sets for all sentences
featuresets = [(document_features(d, word_features), c) for (d, c) in emaildocs]

# %%
# train a classifier and report accuracy
train_set, test_set = featuresets[2700:], featuresets[:2700]
classifier = nltk.NaiveBayesClassifier.train(train_set)
nltk.classify.accuracy(classifier, test_set)
# Out:
# 0.9533333333333334

# %%
classifier.show_most_informative_features(30)
# Out:
# Most Informative Features
#                     V_cc = True              ham : spam   =     32.6 : 1.0
#                   V_2001 = True              ham : spam   =     24.5 : 1.0
#               V_attached = True              ham : spam   =     24.5 : 1.0
#                    V_ect = True              ham : spam   =     22.3 : 1.0
#                    V_hou = True              ham : spam   =     21.6 : 1.0
#                   V_deal = True              ham : spam   =     17.3 : 1.0
#                     V_28 = True              ham : spam   =     16.5 : 1.0
#                   V_file = True              ham : spam   =     15.7 : 1.0
#                  V_money = True             spam : ham    =     15.5 : 1.0
#                 V_robert = True              ham : spam   =     12.1 : 1.0
#                  V_offer = True             spam : ham    =     11.8 : 1.0
#                     V_04 = True              ham : spam   =     11.3 : 1.0
#                 V_online = True             spam : ham    =     10.6 : 1.0
#                     V_02 = True              ham : spam   =      9.9 : 1.0
#                      V_* = True             spam : ham    =      9.7 : 1.0
#                   V_most = True             spam : ham    =      9.4 : 1.0
#                    V_gas = True              ham : spam   =      9.4 : 1.0
#                 V_friday = True              ham : spam   =      9.1 : 1.0
#                   V_corp = True              ham : spam   =      8.9 : 1.0
#                   V_2000 = True              ham : spam   =      8.9 : 1.0
#                    V_low = True             spam : ham    =      8.8 : 1.0
#          V_international = True             spam : ham    =      8.8 : 1.0
#                   V_site = True             spam : ham    =      8.8 : 1.0
#                      V_u = True             spam : ham    =      8.8 : 1.0
#                 V_remove = True             spam : ham    =      8.8 : 1.0
#              V_questions = True              ham : spam   =      8.6 : 1.0
#                      V_j = True              ham : spam   =      8.6 : 1.0
#                      V_. = False            spam : ham    =      8.5 : 1.0
#                V_special = True             spam : ham    =      8.2 : 1.0
#                  V_works = True             spam : ham    =      8.2 : 1.0

# %% [markdown]
# ### 2. Unigram with Non-Alpha Characters Removed

# %%
featuresets = [(document_features(d, filtered_word_features), c) for (d, c) in emaildocs]

# %%
new_train_set, new_test_set = featuresets[2700:], featuresets[:2700]
classifier1 = nltk.NaiveBayesClassifier.train(new_train_set)
nltk.classify.accuracy(classifier1, new_test_set)
# Out:
# 0.9107407407407407

# %%
classifier1.show_most_informative_features(30)
# Out:
# Most Informative Features
#                     V_cc = True              ham : spam   =     32.6 : 1.0
#               V_attached = True              ham : spam   =     24.5 : 1.0
#                    V_ect = True              ham : spam   =     22.3 : 1.0
#                    V_hou = True              ham : spam   =     21.6 : 1.0
#                   V_deal = True              ham : spam   =     17.3 : 1.0
#                   V_file = True              ham : spam   =     15.7 : 1.0
#                  V_money = True             spam : ham    =     15.5 : 1.0
#                 V_robert = True              ham : spam   =     12.1 : 1.0
#                  V_offer = True             spam : ham    =     11.8 : 1.0
#                 V_online = True             spam : ham    =     10.6 : 1.0
#                   V_most = True             spam : ham    =      9.4 : 1.0
#                    V_gas = True              ham : spam   =      9.4 : 1.0
#                 V_friday = True              ham : spam   =      9.1 : 1.0
#                   V_corp = True              ham : spam   =      8.9 : 1.0
#                    V_low = True             spam : ham    =      8.8 : 1.0
#          V_international = True             spam : ham    =      8.8 : 1.0
#                   V_site = True             spam : ham    =      8.8 : 1.0
#                      V_u = True             spam : ham    =      8.8 : 1.0
#                 V_remove = True             spam : ham    =      8.8 : 1.0
#              V_questions = True              ham : spam   =      8.6 : 1.0
#                      V_j = True              ham : spam   =      8.6 : 1.0
#                V_special = True             spam : ham    =      8.2 : 1.0
#                  V_works = True             spam : ham    =      8.2 : 1.0
#                   V_save = True             spam : ham    =      8.2 : 1.0
#                     V_am = True              ham : spam   =      7.8 : 1.0
#                V_changes = True              ham : spam   =      7.7 : 1.0
#               V_thursday = True              ham : spam   =      7.7 : 1.0
#                   V_such = True             spam : ham    =      7.6 : 1.0
#                V_looking = True             spam : ham    =      7.6 : 1.0
#               V_internet = True             spam : ham    =      7.6 : 1.0

# %%
# train classifier and show performance in cross-validation
num_folds = 5
cross_validation_PRF(num_folds, featuresets)
# Out:
# Each fold size: 600
# Label	Precision	Recall		F1
# spam 	      0.938      0.944      0.941
# ham 	      0.942      0.936      0.939
# Label	Precision	Recall		F1
# spam 	      0.887      0.909      0.898
# ham 	      0.921      0.902      0.911
# Label	Precision	Recall		F1
# spam 	      0.993      0.933      0.962
# ham 	      0.932      0.993      0.961
# Label	Precision	Recall		F1
# spam 	      0.968      0.938      0.953
# ham 	      0.931      0.964      0.947
# Label	Precision	Recall		F1
# spam 	      0.951      0.939      0.945
# ham 	      0.935      0.948      0.942

# %% [markdown]
# ### 3. Unigram with Negation Words Removed

# %%
#Create feature set without 
new_NOT_featuresets = [(NOT_features(d, negation_word_features, negationwords), c) for (d, c) in emaildocs]

# %%
new_train_set, new_test_set = new_NOT_featuresets[2700:], new_NOT_featuresets[:2700]
classifier1 = nltk.NaiveBayesClassifier.train(new_train_set)
nltk.classify.accuracy(classifier1, new_test_set)
# Out:
# 0.9507407407407408

# %%
classifier1.show_most_informative_features(30)
# Out:
# Most Informative Features
#                     V_cc = True              ham : spam   =     32.6 : 1.0
#               V_attached = True              ham : spam   =     24.5 : 1.0
#                   V_2001 = True              ham : spam   =     24.5 : 1.0
#                    V_ect = True              ham : spam   =     22.3 : 1.0
#                    V_hou = True              ham : spam   =     21.6 : 1.0
#                   V_deal = True              ham : spam   =     17.3 : 1.0
#                     V_28 = True              ham : spam   =     16.5 : 1.0
#                   V_file = True              ham : spam   =     15.7 : 1.0
#                  V_money = True             spam : ham    =     15.5 : 1.0
#                 V_robert = True              ham : spam   =     12.1 : 1.0
#                  V_offer = True             spam : ham    =     11.8 : 1.0
#                     V_04 = True              ham : spam   =     11.3 : 1.0
#                 V_online = True             spam : ham    =     10.6 : 1.0
#                     V_02 = True              ham : spam   =      9.9 : 1.0
#                      V_* = True             spam : ham    =      9.7 : 1.0
#                   V_most = False            spam : ham    =      9.4 : 1.0
#                    V_gas = True              ham : spam   =      9.4 : 1.0
#                 V_friday = True              ham : spam   =      9.1 : 1.0
#                   V_corp = True              ham : spam   =      8.9 : 1.0
#                   V_2000 = True              ham : spam   =      8.9 : 1.0
#                   V_site = True             spam : ham    =      8.8 : 1.0
#                    V_low = True             spam : ham    =      8.8 : 1.0
#                      V_u = True             spam : ham    =      8.8 : 1.0
#                 V_remove = True             spam : ham    =      8.8 : 1.0
#          V_international = True             spam : ham    =      8.8 : 1.0
#                      V_j = True              ham : spam   =      8.6 : 1.0
#              V_questions = True              ham : spam   =      8.6 : 1.0
#                      V_. = False            spam : ham    =      8.5 : 1.0
#                   V_save = True             spam : ham    =      8.2 : 1.0
#                V_special = True             spam : ham    =      8.2 : 1.0

# %% [markdown]
# ### 4. Unigram with Stop Words Removed

# %%
# use document_features function to create unigram feature sets for all sentences
# using word features with stop words removed
featuresets = [(document_features(d, no_stop_word_features), c) for (d, c) in emaildocs]

# %%
# train a classifier and report accuracy
train_set, test_set = featuresets[2700:], featuresets[:2700]
classifier = nltk.NaiveBayesClassifier.train(train_set)
nltk.classify.accuracy(classifier, test_set)
# Out:
# 0.9403703703703704

# %%
classifier.show_most_informative_features(30)
# Out:
# Most Informative Features
#                     V_cc = True              ham : spam   =     32.6 : 1.0
#                   V_2001 = True              ham : spam   =     24.5 : 1.0
#               V_attached = True              ham : spam   =     24.5 : 1.0
#                    V_ect = True              ham : spam   =     22.3 : 1.0
#                    V_hou = True              ham : spam   =     21.6 : 1.0
#                   V_deal = True              ham : spam   =     17.3 : 1.0
#                     V_28 = True              ham : spam   =     16.5 : 1.0
#                   V_file = True              ham : spam   =     15.7 : 1.0
#                  V_money = True             spam : ham    =     15.5 : 1.0
#                 V_robert = True              ham : spam   =     12.1 : 1.0
#                  V_offer = True             spam : ham    =     11.8 : 1.0
#                     V_04 = True              ham : spam   =     11.3 : 1.0
#                 V_online = True             spam : ham    =     10.6 : 1.0
#                     V_02 = True              ham : spam   =      9.9 : 1.0
#                      V_* = True             spam : ham    =      9.7 : 1.0
#                    V_gas = True              ham : spam   =      9.4 : 1.0
#                 V_friday = True              ham : spam   =      9.1 : 1.0
#                   V_corp = True              ham : spam   =      8.9 : 1.0
#                   V_2000 = True              ham : spam   =      8.9 : 1.0
#                    V_low = True             spam : ham    =      8.8 : 1.0
#          V_international = True             spam : ham    =      8.8 : 1.0
#                   V_site = True             spam : ham    =      8.8 : 1.0
#                      V_u = True             spam : ham    =      8.8 : 1.0
#                 V_remove = True             spam : ham    =      8.8 : 1.0
#              V_questions = True              ham : spam   =      8.6 : 1.0
#                      V_j = True              ham : spam   =      8.6 : 1.0
#                      V_. = False            spam : ham    =      8.5 : 1.0
#                V_special = True             spam : ham    =      8.2 : 1.0
#                  V_works = True             spam : ham    =      8.2 : 1.0
#                   V_save = True             spam : ham    =      8.2 : 1.0

# %% [markdown]
# ### 5. Unigram with Negation Features and Stop Words Removed

# %%
new_NOT_featuresets = [(NOT_features(d, no_stop_word_features, negationwords), c) for (d, c) in emaildocs]

# %%
new_train_set, new_test_set = new_NOT_featuresets[2700:], new_NOT_featuresets[:2700]
classifier1 = nltk.NaiveBayesClassifier.train(new_train_set)
nltk.classify.accuracy(classifier1, new_test_set)
# Out:
# 0.9507407407407408

# %% [markdown]
# ### 6. Bigram Features

# %%
#Create short cut variable name for the bigram association measure
bigram_measures = nltk.collocations.BigramAssocMeasures()
#Create bigram collocation finder using all_words_list
finder = BigramCollocationFinder.from_words(all_words_list)
#Use raw_freq to get bigrams
bigram_features = finder.nbest(bigram_measures.raw_freq, 500)

# %%
# use this function to create feature sets for all sentences
bigram_featuresets = [(bigram_document_features(d, word_features, bigram_features), c) for (d, c) in emaildocs]

# %%
# number of features for document 0
print(len(bigram_featuresets[0][0].keys()))
# Out:
# 2500

# %%
bigram_featuresets[0][0]
# Out:
# {'V_-': True,
#  'V_.': True,
#  'V_,': True,
#  'V_/': True,
#  'V_:': True,
#  'V_the': True,
#  'V_to': True,
#  'V_and': True,
#  'V_of': False,
#  'V_a': False,
#  'V_for': False,
#  'V_ect': False,
#  'V_?': True,
#  'V_in': False,
#  'V_you': True,
#  'V_@': False,
#  'V_this': True,
#  'V_is': True,
#  'V_on': False,
#  'V_=': True,
#  'V_i': False,
#  "V_'": False,
#  'V_)': False,
#  'V_(': False,
#  'V_Subject': True,
#  'V_be': False,
#  'V_!': True,
#  'V_your': False,
#  'V_hou': False,
#  'V_that': False,
#  'V_enron': False,
#  'V_with': False,
#  'V_we': False,
#  'V_from': False,
#  'V_have': False,
#  'V_$': False,
#  'V_will': False,
#  'V_s': False,
#  'V_are': True,
#  'V_or': False,
#  'V_as': False,
#  'V_at': False,
#  'V_;': True,
#  'V_it': False,
#  'V_3': True,
#  'V_not': False,
#  'V_2000': False,
#  'V_com': False,
#  'V__': False,
#  'V_if': False,
#  'V_by': False,
#  'V_please': False,
#  'V_``': False,
#  'V_1': True,
#  'V_2': False,
#  'V_00': False,
#  'V_our': True,
#  'V_me': True,
#  'V_%': False,
#  'V_|': True,
#  'V_all': True,
#  'V_gas': False,
#  'V_>': False,
#  'V_subject': False,
#  'V_#': False,
#  'V_can': True,
#  'V_*': False,
#  'V_any': True,
#  'V_deal': False,
#  'V_d': False,
#  'V_am': False,
#  'V_e': False,
#  'V_10': False,
#  'V_http': False,
#  'V_0': True,
#  'V_000': False,
#  'V_no': True,
#  'V_meter': False,
#  'V_pm': False,
#  'V_an': False,
#  'V_4': False,
#  'V_has': False,
#  'V_hpl': False,
#  'V_cc': False,
#  'V_5': False,
#  'V_re': True,
#  'V_was': False,
#  'V_company': False,
#  'V_2001': False,
#  'V_new': False,
#  'V_t': False,
#  'V_may': False,
#  'V_thanks': False,
#  'V_information': False,
#  'V_get': False,
#  'V_price': False,
#  'V_11': False,
#  'V_up': False,
#  'V_01': False,
#  'V_do': False,
#  'V_daren': False,
#  'V_corp': False,
#  'V_more': True,
#  'V_here': True,
#  'V_need': False,
#  'V_7': True,
#  'V_know': False,
#  'V_us': False,
#  'V_only': False,
#  'V_out': False,
#  'V_these': False,
#  'V_my': False,
#  'V_should': False,
#  'V_www': False,
#  'V_&': False,
#  'V_time': True,
#  'V_there': False,
#  'V_email': False,
#  'V_12': True,
#  'V_but': False,
#  'V_6': False,
#  'V_one': False,
#  'V_been': False,
#  'V_m': False,
#  'V_see': True,
#  'V_message': False,
#  'V_l': False,
#  'V_99': False,
#  'V_8': False,
#  'V_9': False,
#  'V_they': False,
#  'V_p': False,
#  'V_would': False,
#  'V_now': False,
#  'V_mmbtu': False,
#  'V_j': False,
#  'V_into': False,
#  'V_so': False,
#  'V_let': False,
#  'V_forwarded': False,
#  'V_20': False,
#  'V_font': False,
#  'V_about': False,
#  'V_what': False,
#  'V_td': False,
#  'V_30': False,
#  'V_their': False,
#  'V_which': True,
#  'V_statements': False,
#  'V_15': False,
#  'V_+': False,
#  'V_th': False,
#  'V_day': False,
#  'V_farmer': False,
#  'V_over': False,
#  'V_just': False,
#  'V_03': False,
#  'V_02': False,
#  'V_o': False,
#  'V_other': False,
#  'V_also': False,
#  'V_attached': False,
#  'V_[': False,
#  'V_]': False,
#  'V_mail': False,
#  'V_its': False,
#  'V_x': False,
#  'V_b': False,
#  'V_nbsp': False,
#  'V_like': False,
#  'V_c': False,
#  'V_xls': False,
#  'V_some': False,
#  'V_month': False,
#  'V_contact': False,
#  'V_report': False,
#  'V_energy': False,
#  'V_free': False,
#  'V_sent': False,
#  'V_100': False,
#  'V_09': False,
#  'V_want': False,
#  'V_robert': False,
#  'V_05': True,
#  'V_25': False,
#  'V_change': False,
#  'V_r': False,
#  'V_contract': False,
#  'V_volume': False,
#  'V_when': True,
#  'V_within': False,
#  'V_business': False,
#  'V_height': False,
#  'V_inc': False,
#  'V_08': False,
#  'V_order': True,
#  'V_click': False,
#  'V_04': True,
#  'V_who': False,
#  'V_nom': False,
#  'V_deals': False,
#  'V_today': False,
#  'V_could': False,
#  'V_production': False,
#  'V_make': False,
#  'V_questions': False,
#  'V_he': False,
#  'V_call': False,
#  'V_back': False,
#  'V_them': False,
#  'V_sitara': False,
#  'V_stock': False,
#  'V_number': False,
#  'V_go': False,
#  'V_use': False,
#  'V_texas': False,
#  'V_were': False,
#  'V_forward': False,
#  'V_days': False,
#  'V_through': False,
#  'V_money': False,
#  'V_volumes': False,
#  'V_list': False,
#  'V_size': False,
#  'V_pills': True,
#  'V_following': False,
#  'V_below': False,
#  'V_first': False,
#  'V_system': False,
#  'V_bob': False,
#  'V_width': False,
#  'V_u': False,
#  'V_per': False,
#  'V_online': True,
#  'V_best': True,
#  'V_don': False,
#  'V_2004': True,
#  'V_how': False,
#  'V_take': False,
#  'V_investment': False,
#  'V_24': False,
#  'V_06': False,
#  'V_looking': False,
#  'V_net': False,
#  'V_file': False,
#  'V_21': False,
#  'V_pec': False,
#  'V_flow': False,
#  'V_available': True,
#  'V_60': False,
#  'V_well': False,
#  'V_07': False,
#  'V_50': False,
#  'V_products': False,
#  'V_31': False,
#  'V_effective': False,
#  'V_securities': False,
#  'V_sale': False,
#  'V_line': False,
#  'V_than': True,
#  'V_ticket': False,
#  'V_future': False,
#  'V_service': False,
#  'V_prices': False,
#  'V_oil': False,
#  'V_based': False,
#  'V_16': False,
#  'V_less': False,
#  'V_before': False,
#  'V_had': False,
#  'V_n': False,
#  'V_high': False,
#  'V_internet': False,
#  'V_market': False,
#  'V_product': False,
#  'V_713': False,
#  'V_office': False,
#  'V_many': False,
#  'V_original': False,
#  'V_28': False,
#  'V_being': False,
#  'V_after': False,
#  'V_14': False,
#  'V_next': False,
#  'V_help': False,
#  'V_daily': False,
#  'V_account': False,
#  'V_his': False,
#  'V_address': False,
#  'V_march': False,
#  'V_sales': False,
#  'V_news': False,
#  'V_v': False,
#  'V_services': False,
#  'V_computron': False,
#  'V_18': False,
#  'V_she': False,
#  'V_most': False,
#  'V_link': False,
#  'V_send': False,
#  'V_two': False,
#  'V_without': False,
#  'V_align': False,
#  'V_save': False,
#  'V_f': False,
#  'V_week': False,
#  'V_name': False,
#  'V_nomination': False,
#  'V_tr': False,
#  'V_made': False,
#  'V_g': False,
#  'V_due': False,
#  'V_off': False,
#  'V_17': False,
#  'V_22': False,
#  'V_thank': False,
#  'V_mary': False,
#  'V_last': False,
#  'V_23': False,
#  'V_year': False,
#  'V_work': False,
#  'V_info': False,
#  'V_h': False,
#  'V_such': False,
#  'V_software': False,
#  'V_windows': False,
#  'V_w': False,
#  'V_january': False,
#  'V_april': False,
#  'V_plant': False,
#  'V_ena': False,
#  'V_microsoft': False,
#  'V_site': False,
#  'V_under': False,
#  'V_center': False,
#  'V_very': False,
#  'V_july': False,
#  'V_same': False,
#  'V_29': False,
#  'V_40': False,
#  'V_million': False,
#  'V_offer': False,
#  'V_group': False,
#  'V_27': False,
#  'V_each': False,
#  'V_world': False,
#  'V_vance': False,
#  'V_above': False,
#  'V_does': False,
#  'V_said': False,
#  'V_international': False,
#  'V_gary': False,
#  'V_those': False,
#  'V_agreement': False,
#  'V_purchase': False,
#  'V_19': False,
#  'V_69': False,
#  'V_color': False,
#  'V_set': False,
#  'V_face': False,
#  'V_phone': False,
#  'V_find': False,
#  'V_people': False,
#  'V_13': False,
#  'V_pt': False,
#  'V_90': False,
#  'V_then': False,
#  'V_companies': False,
#  'V_professional': False,
#  'V_special': False,
#  'V_border': False,
#  'V_95': False,
#  'V_26': False,
#  'V_45': False,
#  'V_home': False,
#  'V_june': False,
#  'V_look': False,
#  'V_hours': False,
#  'V_needs': False,
#  'V_reply': False,
#  'V_nd': False,
#  'V_href': False,
#  'V_melissa': False,
#  'V_fax': False,
#  "V_''": False,
#  'V_section': False,
#  'V_visit': False,
#  'V_because': False,
#  'V_total': False,
#  'V_delivery': False,
#  'V_teco': False,
#  'V_good': False,
#  'V_management': False,
#  'V_america': False,
#  'V_request': False,
#  'V_viagra': False,
#  'V_receive': False,
#  'V_north': False,
#  'V_k': False,
#  'V_changes': False,
#  'V_give': False,
#  'V_down': False,
#  'V_br': False,
#  'V_buy': False,
#  'V_did': False,
#  'V_think': False,
#  'V_her': False,
#  'V_where': False,
#  'V_check': False,
#  'V_fw': False,
#  'V_houston': False,
#  'V_act': False,
#  'V_performance': False,
#  'V_process': False,
#  'V_low': False,
#  'V_date': True,
#  'V_julie': False,
#  'V_stop': False,
#  'V_advice': False,
#  'V_both': False,
#  'V_tap': False,
#  'V_results': False,
#  'V_stocks': False,
#  'V_long': False,
#  'V_remove': False,
#  'V_every': False,
#  'V_xp': False,
#  'V_security': False,
#  'V_further': False,
#  'V_adobe': False,
#  'V_co': False,
#  'V_own': False,
#  'V_ami': False,
#  'V_hsc': False,
#  'V_120': False,
#  'V_ve': False,
#  'V_pat': False,
#  'V_still': False,
#  'V_ll': False,
#  'V_even': False,
#  'V_tenaska': False,
#  'V_src': False,
#  'V_right': False,
#  'V_much': False,
#  'V_great': False,
#  'V_again': False,
#  'V_susan': False,
#  'V_sure': False,
#  'V_going': False,
#  'V_part': False,
#  'V_show': False,
#  'V_via': False,
#  'V_point': False,
#  'V_george': False,
#  'V_trade': False,
#  'V_rate': False,
#  'V_current': False,
#  'V_63': False,
#  'V_way': False,
#  'V_top': False,
#  'V_pay': True,
#  'V_smith': False,
#  'V_family': False,
#  'V_44': False,
#  'V_shares': False,
#  'V_place': False,
#  'V_lisa': False,
#  'V_cialis': False,
#  'V_cotten': False,
#  'V_works': False,
#  'V_since': False,
#  'V_80': True,
#  'V_customers': True,
#  'V_dollars': False,
#  'V_currently': False,
#  'V_megan': False,
#  'V_actual': False,
#  'V_end': False,
#  'V_must': False,
#  'V_web': False,
#  'V_data': False,
#  'V_friday': False,
#  'V_copy': False,
#  'V_believe': False,
#  'V_desk': False,
#  'V_september': False,
#  'V_taylor': False,
#  'V_august': False,
#  'V_team': False,
#  'V_until': False,
#  'V_st': False,
#  'V_actuals': False,
#  'V_details': False,
#  'V_december': False,
#  'V_2003': False,
#  'V_full': False,
#  'V_hi': False,
#  'V_david': False,
#  'V_transport': False,
#  'V_quality': False,
#  'V_provide': False,
#  'V_500': False,
#  'V_mark': False,
#  'V_received': False,
#  'V_including': False,
#  'V_keep': False,
#  'V_soft': False,
#  'V_come': False,
#  'V_increase': False,
#  'V_98': False,
#  'V_michael': False,
#  'V_customer': False,
#  'V_limited': False,
#  'V_161': False,
#  'V_html': False,
#  'V_term': False,
#  'V_natural': False,
#  'V_newsletter': False,
#  'V_access': False,
#  'V_spot': False,
#  'V_prescription': True,
#  'V_note': False,
#  'V_tickets': False,
#  'V_y': False,
#  'V_needed': False,
#  'V_once': False,
#  'V_able': False,
#  'V_activity': False,
#  'V_read': False,
#  'V_duke': False,
#  'V_financial': False,
#  'V_offers': False,
#  'V_index': False,
#  'V_possible': False,
#  'V_using': False,
#  'V_cd': False,
#  'V_interest': False,
#  'V_steve': False,
#  'V_meds': False,
#  'V_content': True,
#  'V_review': False,
#  'V_while': False,
#  'V_include': False,
#  'V_support': False,
#  'V_past': False,
#  'V_real': False,
#  'V_better': False,
#  'V_style': False,
#  'V_why': True,
#  'V_entered': False,
#  'V_fact': False,
#  'V_tom': False,
#  'V_notice': False,
#  'V_additional': False,
#  'V_iv': False,
#  'V_provided': False,
#  'V_control': False,
#  'V_technology': False,
#  'V_chokshi': False,
#  'V_prior': True,
#  'V_program': False,
#  'V_months': False,
#  'V_id': True,
#  'V_manager': False,
#  'V_revised': False,
#  'V_october': False,
#  'V_`': False,
#  'V_fyi': False,
#  'V_problem': False,
#  'V_transaction': False,
#  'V_used': False,
#  'V_sell': False,
#  'V_life': False,
#  'V_shipping': False,
#  'V_start': False,
#  'V_global': False,
#  'V_feb': False,
#  'V_thru': False,
#  'V_numbers': False,
#  'V_feel': False,
#  'V_unify': False,
#  'V_noms': False,
#  'V_eastrans': False,
#  'V_jackie': False,
#  'V_position': False,
#  'V_party': False,
#  'V_issue': False,
#  'V_continue': False,
#  'V_resources': False,
#  'V_regarding': False,
#  'V_paliourg': True,
#  'V_de': False,
#  'V_paid': False,
#  'V_create': False,
#  'V_32': True,
#  'V_john': False,
#  'V_soon': False,
#  'V_three': False,
#  'V_corporation': False,
#  'V_events': False,
#  'V_investing': False,
#  'V_jan': False,
#  'V_development': False,
#  'V_cost': False,
#  'V_monday': False,
#  'V_risk': False,
#  'V_always': False,
#  'V_regards': False,
#  'V_another': False,
#  'V_put': False,
#  'V_\x01': False,
#  'V_aimee': False,
#  'V_ms': False,
#  'V_counterparty': False,
#  'V_february': False,
#  'V_got': False,
#  'V_move': False,
#  'V_power': False,
#  'V_fee': False,
#  'V_project': False,
#  'V_dec': False,
#  'V_created': False,
#  'V_young': False,
#  'V_fuel': False,
#  'V_meters': False,
#  'V_tu': False,
#  'V_voip': False,
#  'V_demand': False,
#  'V_hplc': False,
#  'V_never': False,
#  'V_brian': False,
#  'V_pipeline': False,
#  'V_pro': False,
#  'V_thursday': False,
#  'V_november': False,
#  'V_him': False,
#  'V_zone': False,
#  'V_industry': False,
#  'V_update': False,
#  'V_type': True,
#  'V_easy': False,
#  'V_someone': False,
#  'V_field': False,
#  'V_estimates': False,
#  'V_clynes': False,
#  'V_supply': False,
#  'V_graves': False,
#  'V_meyers': False,
#  'V_strong': False,
#  'V_35': False,
#  'V_mg': False,
#  'V_oo': False,
#  'V_wish': False,
#  'V_server': False,
#  'V_trading': False,
#  'V_marketing': False,
#  'V_contracts': False,
#  'V_james': False,
#  'V_php': False,
#  'V_registered': False,
#  'V_health': False,
#  'V_cash': False,
#  'V_however': False,
#  'V_done': False,
#  'V_city': False,
#  'V_little': False,
#  'V_page': False,
#  'V_follow': False,
#  'V_bgcolor': False,
#  'V_36': False,
#  'V_either': False,
#  'V_wellhead': False,
#  'V_direct': False,
#  'V_watch': False,
#  'V_china': False,
#  'V_exchange': False,
#  'V_during': False,
#  'V_terms': False,
#  'V_drugs': False,
#  'V_few': False,
#  'V_try': False,
#  'V_unsubscribe': False,
#  'V_rates': False,
#  'V_website': False,
#  'V_private': False,
#  'V_pg': False,
#  'V_lee': False,
#  'V_loss': False,
#  'V_states': False,
#  'V_2005': False,
#  'V_mobile': False,
#  'V_old': False,
#  'V_add': False,
#  'V_area': False,
#  'V_united': False,
#  'V_years': False,
#  'V_tuesday': False,
#  'V_ls': False,
#  'V_error': False,
#  'V_expectations': False,
#  'V_form': False,
#  'V_getting': False,
#  'V_issues': False,
#  'V_transfer': True,
#  'V_material': False,
#  'V_na': False,
#  'V_cause': False,
#  'V_third': False,
#  'V_removed': False,
#  'V_anything': False,
#  'V_suite': False,
#  'V_pain': False,
#  'V_download': False,
#  'V_tx': False,
#  'V_required': True,
#  'V_complete': False,
#  'V_scheduled': False,
#  'V_major': False,
#  'V_big': False,
#  'V_ever': False,
#  'V_love': False,
#  'V_55': False,
#  'V_storage': False,
#  'V_retail': False,
#  'V_personal': False,
#  'V_between': False,
#  'V_might': False,
#  'V_lloyd': False,
#  'V_utilities': False,
#  'V_text': True,
#  'V_computer': False,
#  'V_already': False,
#  'V_risks': False,
#  'V_view': False,
#  'V_rita': False,
#  'V_drive': False,
#  'V_txu': False,
#  'V_gif': False,
#  'V_hanks': False,
#  'V_worldwide': False,
#  'V_release': False,
#  'V_letter': False,
#  'V_bank': False,
#  'V_operations': False,
#  'V_second': False,
#  'V_48': False,
#  'V_tabs': False,
#  'V_biz': False,
#  'V_canada': False,
#  'V_working': False,
#  'V_country': False,
#  'V_im': False,
#  'V_pricing': False,
#  'V_action': False,
#  'V_operating': False,
#  'V_case': False,
#  'V_cs': False,
#  'V_growth': False,
#  'V_credit': False,
#  'V_called': False,
#  'V_mr': False,
#  'V_box': False,
#  'V_too': False,
#  'V_image': False,
#  'V_duty': False,
#  'V_spam': False,
#  'V_man': False,
#  'V_enter': False,
#  'V_person': False,
#  'V_orders': False,
#  'V_ali': False,
#  'V_\\': False,
#  'V_publisher': False,
#  'V_remember': False,
#  'V_confirm': False,
#  'V_commercial': False,
#  'V_howard': False,
#  'V_reason': False,
#  'V_yourself': False,
#  'V_state': False,
#  'V_weight': False,
#  'V_potential': False,
#  'V_70': False,
#  'V_hope': False,
#  'V_iferc': False,
#  'V_meeting': False,
#  'V_differ': False,
#  'V_small': False,
#  'V_browser': False,
#  'V_971': False,
#  'V_press': False,
#  'V_application': False,
#  'V_firm': False,
#  'V_yet': False,
#  'V_sat': False,
#  'V_everyone': False,
#  'V_source': False,
#  'V_jones': False,
#  'V_correct': False,
#  'V_period': False,
#  'V_technologies': False,
#  'V_left': False,
#  'V_200': False,
#  'V_department': False,
#  'V_around': False,
#  'V_wynne': False,
#  'V_morning': False,
#  'V_important': False,
#  'V_charge': False,
#  'V_middle': False,
#  'V_katy': False,
#  'V_survey': False,
#  'V_necessary': False,
#  'V_ces': False,
#  'V_expected': False,
#  'V_kind': False,
#  'V_payment': False,
#  'V_latest': False,
#  'V_super': False,
#  'V_amount': False,
#  'V_mike': False,
#  'V_times': False,
#  'V_south': False,
#  'V_public': False,
#  'V_spreadsheet': False,
#  'V_open': False,
#  'V_compliance': False,
#  'V_late': False,
#  'V_intended': False,
#  'V_thought': False,
#  'V_124': False,
#  'V_really': False,
#  'V_deliveries': False,
#  'V_300': False,
#  'V_expect': False,
#  'V_target': False,
#  'V_anyone': False,
#  'V_federal': False,
#  'V_body': False,
#  'V_pefs': False,
#  'V_mx': False,
#  'V_brand': False,
#  'V_39': False,
#  'V_enronxgate': False,
#  'V_nominations': False,
#  'V_hplno': False,
#  'V_interested': False,
#  'V_wednesday': False,
#  'V_nothing': False,
#  'V_employees': False,
#  'V_lose': False,
#  'V_52': False,
#  'V_meet': False,
#  'V_something': False,
#  'V_table': False,
#  'V_cheap': False,
#  'V_photoshop': False,
#  'V_stack': False,
#  'V_img': False,
#  'V_85': False,
#  'V_found': False,
#  'V_fill': False,
#  'V_plans': False,
#  'V_uncertainties': False,
#  'V_paste': False,
#  'V_al': False,
#  'V_accounting': False,
#  'V_valign': False,
#  'V_users': False,
#  'V_large': False,
#  'V_certain': False,
#  'V_network': False,
#  'V_men': False,
#  'V_sex': False,
#  'V_allocation': False,
#  'V_exploration': False,
#  'V_hard': False,
#  'V_systems': False,
#  'V_everything': False,
#  'V_say': False,
#  'V_camp': False,
#  'V_quick': False,
#  'V_zero': False,
#  'V_write': False,
#  'V_coastal': False,
#  'V_considered': False,
#  'V_sun': False,
#  'V_investors': False,
#  'V_~': False,
#  'V_beaumont': False,
#  'V_gathering': False,
#  'V_meaning': False,
#  'V_publication': False,
#  'V_doc': False,
#  'V_agree': False,
#  'V_jpg': False,
#  'V_sources': False,
#  'V_gco': False,
#  'V_000000': False,
#  'V_version': True,
#  'V_features': False,
#  'V_weeks': False,
#  'V_updated': False,
#  'V_plan': False,
#  'V_usa': False,
#  'V_location': False,
#  'V_katherine': False,
#  'V_div': False,
#  'V_things': False,
#  'V_bill': False,
#  'V_secure': False,
#  'V_fund': False,
#  'V_weissman': False,
#  'V_capital': False,
#  'V_75': False,
#  'V_subscribers': False,
#  'V_featured': False,
#  'V_solution': False,
#  'V_generic': False,
#  'V_hello': False,
#  'V_moopid': False,
#  'V_hotlist': False,
#  'V_user': True,
#  'V_darren': False,
#  'V_advise': False,
#  'V_away': False,
#  'V_hplo': False,
#  'V_parker': False,
#  'V_longer': False,
#  'V_property': False,
#  'V_run': False,
#  'V_lannou': False,
#  'V_pharmacy': True,
#  'V_54': False,
#  'V_beginning': False,
#  'V_38': False,
#  'V_several': False,
#  'V_involve': False,
#  'V_ready': False,
#  'V_sherlyn': False,
#  'V_having': False,
#  'V_offering': False,
#  'V_medical': False,
#  'V_dear': False,
#  'V_recent': False,
#  'V_code': False,
#  'V_vlt': False,
#  'V_thing': False,
#  'V_56': False,
#  'V_projections': False,
#  'V_format': False,
#  'V_given': False,
#  'V_epson': False,
#  'V_pc': False,
#  'V_cut': False,
#  'V_calls': False,
#  'V_music': False,
#  'V_impact': False,
#  'V_safe': False,
#  'V_approved': False,
#  'V_director': False,
#  'V_fuels': False,
#  'V_ic': False,
#  'V_33': False,
#  'V_words': False,
#  'V_path': False,
#  'V_weekend': False,
#  'V_fast': False,
#  'V_approval': False,
#  'V_hot': False,
#  'V_images': False,
#  'V_lst': False,
#  'V_tel': False,
#  'V_availability': False,
#  'V_problems': False,
#  'V_title': False,
#  'V_legal': False,
#  'V_logistics': False,
#  'V_side': False,
#  'V_calpine': False,
#  'V_options': False,
#  'V_47': False,
#  'V_ask': False,
#  'V_shows': False,
#  'V_gr': False,
#  'V_shut': False,
#  'V_book': False,
#  'V_aware': False,
#  'V_completed': False,
#  'V_xanax': False,
#  'V_·': False,
#  'V_imbalance': False,
#  'V_gcs': False,
#  'V_cec': False,
#  'V_htmlimg': False,
#  'V_wanted': False,
#  'V_plus': False,
#  'V_ability': False,
#  'V_800': False,
#  'V_begin': False,
#  ...}

# %%
# train a classifier and report accuracy
train_set, test_set = bigram_featuresets[2700:], bigram_featuresets[:2700]
classifier = nltk.NaiveBayesClassifier.train(train_set)
nltk.classify.accuracy(classifier, test_set)
# Out:
# 0.9551851851851851

# %% [markdown]
# ### 7. Bigram Features with Non-Alpha Characters Removed

# %%
# use this function to create feature sets for all sentences
bigram_featuresets = [(bigram_document_features(d, filtered_word_features, bigram_features), c) for (d, c) in emaildocs]

# %%
# train a classifier and report accuracy
train_set, test_set = bigram_featuresets[2700:], bigram_featuresets[:2700]
classifier = nltk.NaiveBayesClassifier.train(train_set)
nltk.classify.accuracy(classifier, test_set)
# Out:
# 0.9540740740740741

# %% [markdown]
# ### 8. Bigram Features with Stop Words Removed

# %%
# use this function to create feature sets for all sentences
bigram_featuresets = [(bigram_document_features(d, no_stop_word_features, bigram_features), c) for (d, c) in emaildocs]

# %%
# train a classifier and report accuracy
train_set, test_set = bigram_featuresets[2700:], bigram_featuresets[:2700]
classifier = nltk.NaiveBayesClassifier.train(train_set)
nltk.classify.accuracy(classifier, test_set)
# Out:
# 0.9596296296296296

# %% [markdown]
# ### 9. Bigram Features with Negation Words

# %%
# use this function to create feature sets for all sentences
bigram_featuresets = [(bigram_document_features(d, negation_word_features, bigram_features), c) for (d, c) in emaildocs]

# %%
# perform the cross-validation on the featuresets with word features and generate accuracy
num_folds = 5
cross_validation_accuracy(num_folds, bigram_featuresets)
# Out:
# Each fold size: 600
# 0 0.97
# 1 0.9533333333333334
# 2 0.9733333333333334
# 3 0.9616666666666667
# 4 0.965
# mean accuracy 0.9646666666666667

# %% [markdown]
# ### 10. POS Tag Features

# %%
# define feature sets using this function
POS_featuresets = [(POS_features(d, word_features), c) for (d, c) in emaildocs]
# number of features for document 0
print(len(POS_featuresets[0][0].keys()))
# Out:
# 2004

# %%
# the first sentence
print(emaildocs[0])
# the pos tag features for this sentence
print('num nouns', POS_featuresets[0][0]['nouns'])
print('num verbs', POS_featuresets[0][0]['verbs'])
print('num adjectives', POS_featuresets[0][0]['adjectives'])
print('num adverbs', POS_featuresets[0][0]['adverbs'])
# Out:
# (['Subject', ':', 'all', 'me', '^', 'ds', 'here', 'paliourg', 'user', 'id', ':', '3', 'compendia', 'date', ':', 'tue', ',', '05', 'oct', '2004', '04', ':', '12', ':', '32', '-', '0300', 'mime', '-', 'version', ':', '1', '.', '0', 'content', '-', 'type', ':', 'multipart', '/', 'alternative', ';', 'boundary', '=', '-', '-', '886915596469801750', '-', '-', '-', '-', '886915596469801750', 'content', '-', 'type', ':', 'text', '/', 'plain', ';', 'content', '-', 'transfer', '-', 'encoding', ':', '7', 'bit', 'why', 'pay', 'more', 'when', 'you', 'can', 'enjoy', 'the', 'best', 'and', 'cheapest', 'pills', 'online', '?', 'nearly', '80', 'types', 'to', 'choose', 'which', 'makes', 'ours', 'pharmacy', 'the', 'largest', 'and', 'the', 'best', 'available', '.', 'no', 'appointments', '.', 'no', 'waiting', 'rooms', '.', 'no', 'prior', 'prescription', 'required', '.', 'see', 'why', 'our', 'customers', 're', '-', 'order', 'more', 'than', 'any', 'competitor', '!', 'this', 'is', '1', '-', 'time', 'mai', '|', 'ing', '.', 'no', 'removal', 'are', 're', '-', 'qui', '-', 'red', '-', '-', '-', '-', '886915596469801750', '-', '-'], 'spam')
# num nouns 32
# num verbs 11
# num adjectives 17
# num adverbs 4

# %%
# train and test the classifier
train_set, test_set = POS_featuresets[1500:], POS_featuresets[:1500]
classifier = nltk.NaiveBayesClassifier.train(train_set)
nltk.classify.accuracy(classifier, test_set)
# Out:
# 0.95

# %%
# perform the cross-validation on the featuresets with word features and generate accuracy
num_folds = 5
cross_validation_accuracy(num_folds, POS_featuresets)
# Out:
# Each fold size: 600
# 0 0.97
# 1 0.9533333333333334
# 2 0.97
# 3 0.9583333333333334
# 4 0.9633333333333334
# mean accuracy 0.9630000000000001

# %% [markdown]
# ### 10. POS Tag Features with Non-Alpha Characters Removed

# %%
# define feature sets using this POS function and filtered word features
POS_featuresets = [(POS_features(d, filtered_word_features), c) for (d, c) in emaildocs]

# %%
# perform the cross-validation on the featuresets with word features and generate accuracy
num_folds = 5
cross_validation_accuracy(num_folds, POS_featuresets)
# Out:
# Each fold size: 600
# 0 0.9533333333333334
# 1 0.9566666666666667
# 2 0.965
# 3 0.9666666666666667
# 4 0.9716666666666667
# mean accuracy 0.9626666666666667

# %% [markdown]
# ### 11. POS Tag Features with Stop Words Removed

# %%
# define feature sets using this POS function and no stop words features
POS_featuresets = [(POS_features(d, no_stop_word_features), c) for (d, c) in emaildocs]

# %%
# perform the cross-validation on the featuresets with word features and generate accuracy
num_folds = 5
cross_validation_accuracy(num_folds, POS_featuresets)
# Out:
# Each fold size: 600
# 0 0.9683333333333334
# 1 0.9483333333333334
# 2 0.9733333333333334
# 3 0.96
# 4 0.9633333333333334
# mean accuracy 0.9626666666666667

# %% [markdown]
# ### 12. POS Tag Features with Negation Words

# %%
# define feature sets using this POS function and no stop words features
POS_featuresets = [(POS_features(d, negation_word_features), c) for (d, c) in emaildocs]

# %%
# perform the cross-validation on the featuresets with word features and generate accuracy
num_folds = 5
cross_validation_accuracy(num_folds, POS_featuresets)
# Out:
# Each fold size: 600
# 0 0.9683333333333334
# 1 0.9483333333333334
# 2 0.9733333333333334
# 3 0.96
# 4 0.9633333333333334
# mean accuracy 0.9626666666666667

# %% [markdown]
# # 13. Sentiment Analysis

# %%
path = "/Users/michelle.mak/Desktop/Syracuse/IST_664_NLP/Final_Project/subjclueslen1-HLTEMNLP05.tff"
SL = readSubjectivity(path)
# how many words are in the dictionary
len(SL.keys())
# Out:
# 6885

# %%
SL_featuresets = [(SL_features(d, word_features, SL), c) for (d, c) in emaildocs]
len(SL_featuresets)
# Out:
# 3000

# %%
# this gives the label of document 0
print(SL_featuresets[0][1])
# number of features for document 0
len(SL_featuresets[0][0].keys())
# Out:
# spam
# 2002

# %%
SL_featuresets[0][0]
# Out:
# {'V_-': True,
#  'V_.': True,
#  'V_,': True,
#  'V_/': True,
#  'V_:': True,
#  'V_the': True,
#  'V_to': True,
#  'V_and': True,
#  'V_of': False,
#  'V_a': False,
#  'V_for': False,
#  'V_ect': False,
#  'V_?': True,
#  'V_in': False,
#  'V_you': True,
#  'V_@': False,
#  'V_this': True,
#  'V_is': True,
#  'V_on': False,
#  'V_=': True,
#  'V_i': False,
#  "V_'": False,
#  'V_)': False,
#  'V_(': False,
#  'V_Subject': True,
#  'V_be': False,
#  'V_!': True,
#  'V_your': False,
#  'V_hou': False,
#  'V_that': False,
#  'V_enron': False,
#  'V_with': False,
#  'V_we': False,
#  'V_from': False,
#  'V_have': False,
#  'V_$': False,
#  'V_will': False,
#  'V_s': False,
#  'V_are': True,
#  'V_or': False,
#  'V_as': False,
#  'V_at': False,
#  'V_;': True,
#  'V_it': False,
#  'V_3': True,
#  'V_not': False,
#  'V_2000': False,
#  'V_com': False,
#  'V__': False,
#  'V_if': False,
#  'V_by': False,
#  'V_please': False,
#  'V_``': False,
#  'V_1': True,
#  'V_2': False,
#  'V_00': False,
#  'V_our': True,
#  'V_me': True,
#  'V_%': False,
#  'V_|': True,
#  'V_all': True,
#  'V_gas': False,
#  'V_>': False,
#  'V_subject': False,
#  'V_#': False,
#  'V_can': True,
#  'V_*': False,
#  'V_any': True,
#  'V_deal': False,
#  'V_d': False,
#  'V_am': False,
#  'V_e': False,
#  'V_10': False,
#  'V_http': False,
#  'V_0': True,
#  'V_000': False,
#  'V_no': True,
#  'V_meter': False,
#  'V_pm': False,
#  'V_an': False,
#  'V_4': False,
#  'V_has': False,
#  'V_hpl': False,
#  'V_cc': False,
#  'V_5': False,
#  'V_re': True,
#  'V_was': False,
#  'V_company': False,
#  'V_2001': False,
#  'V_new': False,
#  'V_t': False,
#  'V_may': False,
#  'V_thanks': False,
#  'V_information': False,
#  'V_get': False,
#  'V_price': False,
#  'V_11': False,
#  'V_up': False,
#  'V_01': False,
#  'V_do': False,
#  'V_daren': False,
#  'V_corp': False,
#  'V_more': True,
#  'V_here': True,
#  'V_need': False,
#  'V_7': True,
#  'V_know': False,
#  'V_us': False,
#  'V_only': False,
#  'V_out': False,
#  'V_these': False,
#  'V_my': False,
#  'V_should': False,
#  'V_www': False,
#  'V_&': False,
#  'V_time': True,
#  'V_there': False,
#  'V_email': False,
#  'V_12': True,
#  'V_but': False,
#  'V_6': False,
#  'V_one': False,
#  'V_been': False,
#  'V_m': False,
#  'V_see': True,
#  'V_message': False,
#  'V_l': False,
#  'V_99': False,
#  'V_8': False,
#  'V_9': False,
#  'V_they': False,
#  'V_p': False,
#  'V_would': False,
#  'V_now': False,
#  'V_mmbtu': False,
#  'V_j': False,
#  'V_into': False,
#  'V_so': False,
#  'V_let': False,
#  'V_forwarded': False,
#  'V_20': False,
#  'V_font': False,
#  'V_about': False,
#  'V_what': False,
#  'V_td': False,
#  'V_30': False,
#  'V_their': False,
#  'V_which': True,
#  'V_statements': False,
#  'V_15': False,
#  'V_+': False,
#  'V_th': False,
#  'V_day': False,
#  'V_farmer': False,
#  'V_over': False,
#  'V_just': False,
#  'V_03': False,
#  'V_02': False,
#  'V_o': False,
#  'V_other': False,
#  'V_also': False,
#  'V_attached': False,
#  'V_[': False,
#  'V_]': False,
#  'V_mail': False,
#  'V_its': False,
#  'V_x': False,
#  'V_b': False,
#  'V_nbsp': False,
#  'V_like': False,
#  'V_c': False,
#  'V_xls': False,
#  'V_some': False,
#  'V_month': False,
#  'V_contact': False,
#  'V_report': False,
#  'V_energy': False,
#  'V_free': False,
#  'V_sent': False,
#  'V_100': False,
#  'V_09': False,
#  'V_want': False,
#  'V_robert': False,
#  'V_05': True,
#  'V_25': False,
#  'V_change': False,
#  'V_r': False,
#  'V_contract': False,
#  'V_volume': False,
#  'V_when': True,
#  'V_within': False,
#  'V_business': False,
#  'V_height': False,
#  'V_inc': False,
#  'V_08': False,
#  'V_order': True,
#  'V_click': False,
#  'V_04': True,
#  'V_who': False,
#  'V_nom': False,
#  'V_deals': False,
#  'V_today': False,
#  'V_could': False,
#  'V_production': False,
#  'V_make': False,
#  'V_questions': False,
#  'V_he': False,
#  'V_call': False,
#  'V_back': False,
#  'V_them': False,
#  'V_sitara': False,
#  'V_stock': False,
#  'V_number': False,
#  'V_go': False,
#  'V_use': False,
#  'V_texas': False,
#  'V_were': False,
#  'V_forward': False,
#  'V_days': False,
#  'V_through': False,
#  'V_money': False,
#  'V_volumes': False,
#  'V_list': False,
#  'V_size': False,
#  'V_pills': True,
#  'V_following': False,
#  'V_below': False,
#  'V_first': False,
#  'V_system': False,
#  'V_bob': False,
#  'V_width': False,
#  'V_u': False,
#  'V_per': False,
#  'V_online': True,
#  'V_best': True,
#  'V_don': False,
#  'V_2004': True,
#  'V_how': False,
#  'V_take': False,
#  'V_investment': False,
#  'V_24': False,
#  'V_06': False,
#  'V_looking': False,
#  'V_net': False,
#  'V_file': False,
#  'V_21': False,
#  'V_pec': False,
#  'V_flow': False,
#  'V_available': True,
#  'V_60': False,
#  'V_well': False,
#  'V_07': False,
#  'V_50': False,
#  'V_products': False,
#  'V_31': False,
#  'V_effective': False,
#  'V_securities': False,
#  'V_sale': False,
#  'V_line': False,
#  'V_than': True,
#  'V_ticket': False,
#  'V_future': False,
#  'V_service': False,
#  'V_prices': False,
#  'V_oil': False,
#  'V_based': False,
#  'V_16': False,
#  'V_less': False,
#  'V_before': False,
#  'V_had': False,
#  'V_n': False,
#  'V_high': False,
#  'V_internet': False,
#  'V_market': False,
#  'V_product': False,
#  'V_713': False,
#  'V_office': False,
#  'V_many': False,
#  'V_original': False,
#  'V_28': False,
#  'V_being': False,
#  'V_after': False,
#  'V_14': False,
#  'V_next': False,
#  'V_help': False,
#  'V_daily': False,
#  'V_account': False,
#  'V_his': False,
#  'V_address': False,
#  'V_march': False,
#  'V_sales': False,
#  'V_news': False,
#  'V_v': False,
#  'V_services': False,
#  'V_computron': False,
#  'V_18': False,
#  'V_she': False,
#  'V_most': False,
#  'V_link': False,
#  'V_send': False,
#  'V_two': False,
#  'V_without': False,
#  'V_align': False,
#  'V_save': False,
#  'V_f': False,
#  'V_week': False,
#  'V_name': False,
#  'V_nomination': False,
#  'V_tr': False,
#  'V_made': False,
#  'V_g': False,
#  'V_due': False,
#  'V_off': False,
#  'V_17': False,
#  'V_22': False,
#  'V_thank': False,
#  'V_mary': False,
#  'V_last': False,
#  'V_23': False,
#  'V_year': False,
#  'V_work': False,
#  'V_info': False,
#  'V_h': False,
#  'V_such': False,
#  'V_software': False,
#  'V_windows': False,
#  'V_w': False,
#  'V_january': False,
#  'V_april': False,
#  'V_plant': False,
#  'V_ena': False,
#  'V_microsoft': False,
#  'V_site': False,
#  'V_under': False,
#  'V_center': False,
#  'V_very': False,
#  'V_july': False,
#  'V_same': False,
#  'V_29': False,
#  'V_40': False,
#  'V_million': False,
#  'V_offer': False,
#  'V_group': False,
#  'V_27': False,
#  'V_each': False,
#  'V_world': False,
#  'V_vance': False,
#  'V_above': False,
#  'V_does': False,
#  'V_said': False,
#  'V_international': False,
#  'V_gary': False,
#  'V_those': False,
#  'V_agreement': False,
#  'V_purchase': False,
#  'V_19': False,
#  'V_69': False,
#  'V_color': False,
#  'V_set': False,
#  'V_face': False,
#  'V_phone': False,
#  'V_find': False,
#  'V_people': False,
#  'V_13': False,
#  'V_pt': False,
#  'V_90': False,
#  'V_then': False,
#  'V_companies': False,
#  'V_professional': False,
#  'V_special': False,
#  'V_border': False,
#  'V_95': False,
#  'V_26': False,
#  'V_45': False,
#  'V_home': False,
#  'V_june': False,
#  'V_look': False,
#  'V_hours': False,
#  'V_needs': False,
#  'V_reply': False,
#  'V_nd': False,
#  'V_href': False,
#  'V_melissa': False,
#  'V_fax': False,
#  "V_''": False,
#  'V_section': False,
#  'V_visit': False,
#  'V_because': False,
#  'V_total': False,
#  'V_delivery': False,
#  'V_teco': False,
#  'V_good': False,
#  'V_management': False,
#  'V_america': False,
#  'V_request': False,
#  'V_viagra': False,
#  'V_receive': False,
#  'V_north': False,
#  'V_k': False,
#  'V_changes': False,
#  'V_give': False,
#  'V_down': False,
#  'V_br': False,
#  'V_buy': False,
#  'V_did': False,
#  'V_think': False,
#  'V_her': False,
#  'V_where': False,
#  'V_check': False,
#  'V_fw': False,
#  'V_houston': False,
#  'V_act': False,
#  'V_performance': False,
#  'V_process': False,
#  'V_low': False,
#  'V_date': True,
#  'V_julie': False,
#  'V_stop': False,
#  'V_advice': False,
#  'V_both': False,
#  'V_tap': False,
#  'V_results': False,
#  'V_stocks': False,
#  'V_long': False,
#  'V_remove': False,
#  'V_every': False,
#  'V_xp': False,
#  'V_security': False,
#  'V_further': False,
#  'V_adobe': False,
#  'V_co': False,
#  'V_own': False,
#  'V_ami': False,
#  'V_hsc': False,
#  'V_120': False,
#  'V_ve': False,
#  'V_pat': False,
#  'V_still': False,
#  'V_ll': False,
#  'V_even': False,
#  'V_tenaska': False,
#  'V_src': False,
#  'V_right': False,
#  'V_much': False,
#  'V_great': False,
#  'V_again': False,
#  'V_susan': False,
#  'V_sure': False,
#  'V_going': False,
#  'V_part': False,
#  'V_show': False,
#  'V_via': False,
#  'V_point': False,
#  'V_george': False,
#  'V_trade': False,
#  'V_rate': False,
#  'V_current': False,
#  'V_63': False,
#  'V_way': False,
#  'V_top': False,
#  'V_pay': True,
#  'V_smith': False,
#  'V_family': False,
#  'V_44': False,
#  'V_shares': False,
#  'V_place': False,
#  'V_lisa': False,
#  'V_cialis': False,
#  'V_cotten': False,
#  'V_works': False,
#  'V_since': False,
#  'V_80': True,
#  'V_customers': True,
#  'V_dollars': False,
#  'V_currently': False,
#  'V_megan': False,
#  'V_actual': False,
#  'V_end': False,
#  'V_must': False,
#  'V_web': False,
#  'V_data': False,
#  'V_friday': False,
#  'V_copy': False,
#  'V_believe': False,
#  'V_desk': False,
#  'V_september': False,
#  'V_taylor': False,
#  'V_august': False,
#  'V_team': False,
#  'V_until': False,
#  'V_st': False,
#  'V_actuals': False,
#  'V_details': False,
#  'V_december': False,
#  'V_2003': False,
#  'V_full': False,
#  'V_hi': False,
#  'V_david': False,
#  'V_transport': False,
#  'V_quality': False,
#  'V_provide': False,
#  'V_500': False,
#  'V_mark': False,
#  'V_received': False,
#  'V_including': False,
#  'V_keep': False,
#  'V_soft': False,
#  'V_come': False,
#  'V_increase': False,
#  'V_98': False,
#  'V_michael': False,
#  'V_customer': False,
#  'V_limited': False,
#  'V_161': False,
#  'V_html': False,
#  'V_term': False,
#  'V_natural': False,
#  'V_newsletter': False,
#  'V_access': False,
#  'V_spot': False,
#  'V_prescription': True,
#  'V_note': False,
#  'V_tickets': False,
#  'V_y': False,
#  'V_needed': False,
#  'V_once': False,
#  'V_able': False,
#  'V_activity': False,
#  'V_read': False,
#  'V_duke': False,
#  'V_financial': False,
#  'V_offers': False,
#  'V_index': False,
#  'V_possible': False,
#  'V_using': False,
#  'V_cd': False,
#  'V_interest': False,
#  'V_steve': False,
#  'V_meds': False,
#  'V_content': True,
#  'V_review': False,
#  'V_while': False,
#  'V_include': False,
#  'V_support': False,
#  'V_past': False,
#  'V_real': False,
#  'V_better': False,
#  'V_style': False,
#  'V_why': True,
#  'V_entered': False,
#  'V_fact': False,
#  'V_tom': False,
#  'V_notice': False,
#  'V_additional': False,
#  'V_iv': False,
#  'V_provided': False,
#  'V_control': False,
#  'V_technology': False,
#  'V_chokshi': False,
#  'V_prior': True,
#  'V_program': False,
#  'V_months': False,
#  'V_id': True,
#  'V_manager': False,
#  'V_revised': False,
#  'V_october': False,
#  'V_`': False,
#  'V_fyi': False,
#  'V_problem': False,
#  'V_transaction': False,
#  'V_used': False,
#  'V_sell': False,
#  'V_life': False,
#  'V_shipping': False,
#  'V_start': False,
#  'V_global': False,
#  'V_feb': False,
#  'V_thru': False,
#  'V_numbers': False,
#  'V_feel': False,
#  'V_unify': False,
#  'V_noms': False,
#  'V_eastrans': False,
#  'V_jackie': False,
#  'V_position': False,
#  'V_party': False,
#  'V_issue': False,
#  'V_continue': False,
#  'V_resources': False,
#  'V_regarding': False,
#  'V_paliourg': True,
#  'V_de': False,
#  'V_paid': False,
#  'V_create': False,
#  'V_32': True,
#  'V_john': False,
#  'V_soon': False,
#  'V_three': False,
#  'V_corporation': False,
#  'V_events': False,
#  'V_investing': False,
#  'V_jan': False,
#  'V_development': False,
#  'V_cost': False,
#  'V_monday': False,
#  'V_risk': False,
#  'V_always': False,
#  'V_regards': False,
#  'V_another': False,
#  'V_put': False,
#  'V_\x01': False,
#  'V_aimee': False,
#  'V_ms': False,
#  'V_counterparty': False,
#  'V_february': False,
#  'V_got': False,
#  'V_move': False,
#  'V_power': False,
#  'V_fee': False,
#  'V_project': False,
#  'V_dec': False,
#  'V_created': False,
#  'V_young': False,
#  'V_fuel': False,
#  'V_meters': False,
#  'V_tu': False,
#  'V_voip': False,
#  'V_demand': False,
#  'V_hplc': False,
#  'V_never': False,
#  'V_brian': False,
#  'V_pipeline': False,
#  'V_pro': False,
#  'V_thursday': False,
#  'V_november': False,
#  'V_him': False,
#  'V_zone': False,
#  'V_industry': False,
#  'V_update': False,
#  'V_type': True,
#  'V_easy': False,
#  'V_someone': False,
#  'V_field': False,
#  'V_estimates': False,
#  'V_clynes': False,
#  'V_supply': False,
#  'V_graves': False,
#  'V_meyers': False,
#  'V_strong': False,
#  'V_35': False,
#  'V_mg': False,
#  'V_oo': False,
#  'V_wish': False,
#  'V_server': False,
#  'V_trading': False,
#  'V_marketing': False,
#  'V_contracts': False,
#  'V_james': False,
#  'V_php': False,
#  'V_registered': False,
#  'V_health': False,
#  'V_cash': False,
#  'V_however': False,
#  'V_done': False,
#  'V_city': False,
#  'V_little': False,
#  'V_page': False,
#  'V_follow': False,
#  'V_bgcolor': False,
#  'V_36': False,
#  'V_either': False,
#  'V_wellhead': False,
#  'V_direct': False,
#  'V_watch': False,
#  'V_china': False,
#  'V_exchange': False,
#  'V_during': False,
#  'V_terms': False,
#  'V_drugs': False,
#  'V_few': False,
#  'V_try': False,
#  'V_unsubscribe': False,
#  'V_rates': False,
#  'V_website': False,
#  'V_private': False,
#  'V_pg': False,
#  'V_lee': False,
#  'V_loss': False,
#  'V_states': False,
#  'V_2005': False,
#  'V_mobile': False,
#  'V_old': False,
#  'V_add': False,
#  'V_area': False,
#  'V_united': False,
#  'V_years': False,
#  'V_tuesday': False,
#  'V_ls': False,
#  'V_error': False,
#  'V_expectations': False,
#  'V_form': False,
#  'V_getting': False,
#  'V_issues': False,
#  'V_transfer': True,
#  'V_material': False,
#  'V_na': False,
#  'V_cause': False,
#  'V_third': False,
#  'V_removed': False,
#  'V_anything': False,
#  'V_suite': False,
#  'V_pain': False,
#  'V_download': False,
#  'V_tx': False,
#  'V_required': True,
#  'V_complete': False,
#  'V_scheduled': False,
#  'V_major': False,
#  'V_big': False,
#  'V_ever': False,
#  'V_love': False,
#  'V_55': False,
#  'V_storage': False,
#  'V_retail': False,
#  'V_personal': False,
#  'V_between': False,
#  'V_might': False,
#  'V_lloyd': False,
#  'V_utilities': False,
#  'V_text': True,
#  'V_computer': False,
#  'V_already': False,
#  'V_risks': False,
#  'V_view': False,
#  'V_rita': False,
#  'V_drive': False,
#  'V_txu': False,
#  'V_gif': False,
#  'V_hanks': False,
#  'V_worldwide': False,
#  'V_release': False,
#  'V_letter': False,
#  'V_bank': False,
#  'V_operations': False,
#  'V_second': False,
#  'V_48': False,
#  'V_tabs': False,
#  'V_biz': False,
#  'V_canada': False,
#  'V_working': False,
#  'V_country': False,
#  'V_im': False,
#  'V_pricing': False,
#  'V_action': False,
#  'V_operating': False,
#  'V_case': False,
#  'V_cs': False,
#  'V_growth': False,
#  'V_credit': False,
#  'V_called': False,
#  'V_mr': False,
#  'V_box': False,
#  'V_too': False,
#  'V_image': False,
#  'V_duty': False,
#  'V_spam': False,
#  'V_man': False,
#  'V_enter': False,
#  'V_person': False,
#  'V_orders': False,
#  'V_ali': False,
#  'V_\\': False,
#  'V_publisher': False,
#  'V_remember': False,
#  'V_confirm': False,
#  'V_commercial': False,
#  'V_howard': False,
#  'V_reason': False,
#  'V_yourself': False,
#  'V_state': False,
#  'V_weight': False,
#  'V_potential': False,
#  'V_70': False,
#  'V_hope': False,
#  'V_iferc': False,
#  'V_meeting': False,
#  'V_differ': False,
#  'V_small': False,
#  'V_browser': False,
#  'V_971': False,
#  'V_press': False,
#  'V_application': False,
#  'V_firm': False,
#  'V_yet': False,
#  'V_sat': False,
#  'V_everyone': False,
#  'V_source': False,
#  'V_jones': False,
#  'V_correct': False,
#  'V_period': False,
#  'V_technologies': False,
#  'V_left': False,
#  'V_200': False,
#  'V_department': False,
#  'V_around': False,
#  'V_wynne': False,
#  'V_morning': False,
#  'V_important': False,
#  'V_charge': False,
#  'V_middle': False,
#  'V_katy': False,
#  'V_survey': False,
#  'V_necessary': False,
#  'V_ces': False,
#  'V_expected': False,
#  'V_kind': False,
#  'V_payment': False,
#  'V_latest': False,
#  'V_super': False,
#  'V_amount': False,
#  'V_mike': False,
#  'V_times': False,
#  'V_south': False,
#  'V_public': False,
#  'V_spreadsheet': False,
#  'V_open': False,
#  'V_compliance': False,
#  'V_late': False,
#  'V_intended': False,
#  'V_thought': False,
#  'V_124': False,
#  'V_really': False,
#  'V_deliveries': False,
#  'V_300': False,
#  'V_expect': False,
#  'V_target': False,
#  'V_anyone': False,
#  'V_federal': False,
#  'V_body': False,
#  'V_pefs': False,
#  'V_mx': False,
#  'V_brand': False,
#  'V_39': False,
#  'V_enronxgate': False,
#  'V_nominations': False,
#  'V_hplno': False,
#  'V_interested': False,
#  'V_wednesday': False,
#  'V_nothing': False,
#  'V_employees': False,
#  'V_lose': False,
#  'V_52': False,
#  'V_meet': False,
#  'V_something': False,
#  'V_table': False,
#  'V_cheap': False,
#  'V_photoshop': False,
#  'V_stack': False,
#  'V_img': False,
#  'V_85': False,
#  'V_found': False,
#  'V_fill': False,
#  'V_plans': False,
#  'V_uncertainties': False,
#  'V_paste': False,
#  'V_al': False,
#  'V_accounting': False,
#  'V_valign': False,
#  'V_users': False,
#  'V_large': False,
#  'V_certain': False,
#  'V_network': False,
#  'V_men': False,
#  'V_sex': False,
#  'V_allocation': False,
#  'V_exploration': False,
#  'V_hard': False,
#  'V_systems': False,
#  'V_everything': False,
#  'V_say': False,
#  'V_camp': False,
#  'V_quick': False,
#  'V_zero': False,
#  'V_write': False,
#  'V_coastal': False,
#  'V_considered': False,
#  'V_sun': False,
#  'V_investors': False,
#  'V_~': False,
#  'V_beaumont': False,
#  'V_gathering': False,
#  'V_meaning': False,
#  'V_publication': False,
#  'V_doc': False,
#  'V_agree': False,
#  'V_jpg': False,
#  'V_sources': False,
#  'V_gco': False,
#  'V_000000': False,
#  'V_version': True,
#  'V_features': False,
#  'V_weeks': False,
#  'V_updated': False,
#  'V_plan': False,
#  'V_usa': False,
#  'V_location': False,
#  'V_katherine': False,
#  'V_div': False,
#  'V_things': False,
#  'V_bill': False,
#  'V_secure': False,
#  'V_fund': False,
#  'V_weissman': False,
#  'V_capital': False,
#  'V_75': False,
#  'V_subscribers': False,
#  'V_featured': False,
#  'V_solution': False,
#  'V_generic': False,
#  'V_hello': False,
#  'V_moopid': False,
#  'V_hotlist': False,
#  'V_user': True,
#  'V_darren': False,
#  'V_advise': False,
#  'V_away': False,
#  'V_hplo': False,
#  'V_parker': False,
#  'V_longer': False,
#  'V_property': False,
#  'V_run': False,
#  'V_lannou': False,
#  'V_pharmacy': True,
#  'V_54': False,
#  'V_beginning': False,
#  'V_38': False,
#  'V_several': False,
#  'V_involve': False,
#  'V_ready': False,
#  'V_sherlyn': False,
#  'V_having': False,
#  'V_offering': False,
#  'V_medical': False,
#  'V_dear': False,
#  'V_recent': False,
#  'V_code': False,
#  'V_vlt': False,
#  'V_thing': False,
#  'V_56': False,
#  'V_projections': False,
#  'V_format': False,
#  'V_given': False,
#  'V_epson': False,
#  'V_pc': False,
#  'V_cut': False,
#  'V_calls': False,
#  'V_music': False,
#  'V_impact': False,
#  'V_safe': False,
#  'V_approved': False,
#  'V_director': False,
#  'V_fuels': False,
#  'V_ic': False,
#  'V_33': False,
#  'V_words': False,
#  'V_path': False,
#  'V_weekend': False,
#  'V_fast': False,
#  'V_approval': False,
#  'V_hot': False,
#  'V_images': False,
#  'V_lst': False,
#  'V_tel': False,
#  'V_availability': False,
#  'V_problems': False,
#  'V_title': False,
#  'V_legal': False,
#  'V_logistics': False,
#  'V_side': False,
#  'V_calpine': False,
#  'V_options': False,
#  'V_47': False,
#  'V_ask': False,
#  'V_shows': False,
#  'V_gr': False,
#  'V_shut': False,
#  'V_book': False,
#  'V_aware': False,
#  'V_completed': False,
#  'V_xanax': False,
#  'V_·': False,
#  'V_imbalance': False,
#  'V_gcs': False,
#  'V_cec': False,
#  'V_htmlimg': False,
#  'V_wanted': False,
#  'V_plus': False,
#  'V_ability': False,
#  'V_800': False,
#  'V_begin': False,
#  ...}

# %%
# train the classifier using these features
train_set, test_set = SL_featuresets[2700:], SL_featuresets[:2700]
classifier = nltk.NaiveBayesClassifier.train(train_set)
nltk.classify.accuracy(classifier, test_set)
# Out:
# 0.952962962962963

# %% [markdown]
# ### 14. Sentiment with Non-Alpha Characters Removed

# %%
#word_features has non-alpha characters removed from code above
SL_featuresets = [(SL_features(d, word_features, SL), c) for (d, c) in emaildocs]

# %%
# train the classifier using these features
train_set, test_set = SL_featuresets[2700:], SL_featuresets[:2700]
classifier = nltk.NaiveBayesClassifier.train(train_set)
nltk.classify.accuracy(classifier, test_set)
# Out:
# 0.952962962962963

# %%
# perform the cross-validation on the featuresets with word features and generate accuracy
num_folds = 10
cross_validation_accuracy(num_folds, SL_featuresets)
# Out:
# Each fold size: 300
# 0 0.97
# 1 0.9766666666666667
# 2 0.96
# 3 0.9566666666666667
# 4 0.96
# 5 0.97
# 6 0.9633333333333334
# 7 0.9566666666666667
# 8 0.96
# 9 0.9666666666666667
# mean accuracy 0.9639999999999999

# %% [markdown]
# ### 15. Sci-Kit Learn with Unigram Featureset

# %%
# use document_features function to create unigram feature sets for all sentences
featuresets = [(document_features(d, word_features), c) for (d, c) in emaildocs]

# %%
# write the feature sets to the csv file
outpath = '/Users/michelle.mak/Desktop/Syracuse/IST_664_NLP/Final_Project/SK_Features.csv'
writeFeatureSets(featuresets, outpath)

# %%
# read in the csv file to use with sk-learn
sk_featureset = pd.read_csv(outpath, encoding="latin-1")
sk_featureset.head()
# Out:
#      V_-   V_.  V_CM    V_/   V_:  V_the  V_to  V_and   V_of    V_a  ...    \
# 0   True  True  True   True  True   True  True   True  False  False  ...
# 1  False  True  True  False  True  False  True  False  False   True  ...
# 2  False  True  True  False  True   True  True  False   True   True  ...
# 3   True  True  True   True  True   True  True   True   True   True  ...
# 4  False  True  True  False  True   True  True  False   True  False  ...
#
#    V_issued  V_significant  V_consumers  V_west  V_missing  V_lines  \
# 0     False          False        False   False      False    False
# 1     False          False        False   False      False    False
# 2     False          False        False   False      False    False
# 3     False          False        False   False      False    False
# 4     False          False        False   False      False    False
#
#    V_proprietary  V_rom  V_consultation  class
# 0          False  False           False   spam
# 1          False  False           False   spam
# 2          False  False           False    ham
# 3          False  False           False   spam
# 4          False  False           False   spam
#
# [5 rows x 2001 columns]

# %%
#Split out the data and the labels
X = pd.DataFrame(sk_featureset.iloc[:,:-1])
y = pd.factorize(sk_featureset.loc[:,'class'])[0]

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2) # 70% training and 30% test

# %%
#Create a Gaussian Classifier
clf=RandomForestClassifier(n_estimators=100)

# %%
#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(X_train,y_train)

y_pred=clf.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.98

# %%
feature_imp = pd.Series(clf.feature_importances_,index=X.columns).sort_values(ascending=False)
feature_imp[:20]
# Out:
# V_enron        0.033643
# V_hpl          0.031338
# V_!            0.026381
# V_daren        0.024649
# V_2000         0.023860
# V_gas          0.018219
# V_thanks       0.017431
# V_2001         0.017046
# V_http         0.016525
# V_deal         0.014007
# V_attached     0.013012
# V_forwarded    0.012765
# V_am           0.012648
# V_your         0.011862
# V_cc           0.011767
# V_subject      0.010758
# V_please       0.010306
# V_%            0.009929
# V_nom          0.009242
# V_questions    0.009187
# dtype: float64

# %%
# Creating a bar plot
sns.barplot(x=feature_imp[:20], y=feature_imp[:20].index)
# Add labels to your graph
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.title("Visualizing Important Features")
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ### Term Frequency Inverse Data Frequency

# %%
# Create frequency distribution of the top 50 words from both data sets.
# Since the word frequency items are a pair of (word, frequency), 
# we can use item[0] to get the word and item[1] to get the frequency.  
# Printing the string ‘\t’ inserts a tab into the output, 
# so that the frequency numbers line up.

## Using Spam
fdist = nltk.FreqDist(all_words_list)
fdistkeys = list(fdist.keys())
fdistkeys[:2000]

topkeys = fdist.most_common(2000)
#for pair in topkeys:
    #print(pair)

# Normalize
numwords = len(all_words_list)
topkeysnormalized = [(word, freq / numwords) for (word, freq) in topkeys]
topkeysnormalized[:20]
# Out:
# [('-', 0.05711704535804125),
#  ('.', 0.048185414793708616),
#  (',', 0.03375863512971363),
#  ('/', 0.030060061555040807),
#  (':', 0.023412585692406358),
#  ('the', 0.021509123440991207),
#  ('to', 0.01642248662451718),
#  ('and', 0.011887853860953547),
#  ('of', 0.009936072952387088),
#  ('a', 0.00912051258774229),
#  ('for', 0.0082976312144382),
#  ('ect', 0.007886190527786156),
#  ('?', 0.007461572025547392),
#  ('in', 0.0073063666419704645),
#  ('you', 0.007217050336327138),
#  ('@', 0.0071526254601253945),
#  ('this', 0.006285818034865572),
#  ('is', 0.00609986441491963),
#  ('on', 0.005484899687539351),
#  ('=', 0.005237449594855381)]

# %%
# use document_features function to create unigram feature sets for all sentences
TFIDF_featuresets = [(TFIDF_document_features(d, word_features), c) for (d, c) in emaildocs]

# %%
len(TFIDF_featuresets[0][0])
# Out:
# 2000

# %%
print(TFIDF_featuresets[0][0])
print(TFIDF_featuresets[0][1])
# Out:
# {'V_-': 0.05711704535804125, 'V_.': 0.048185414793708616, 'V_,': 0.03375863512971363, 'V_/': 0.030060061555040807, 'V_:': 0.023412585692406358, 'V_the': 0.021509123440991207, 'V_to': 0.01642248662451718, 'V_and': 0.011887853860953547, 'V_of': 0, 'V_a': 0, 'V_for': 0, 'V_ect': 0, 'V_?': 0.007461572025547392, 'V_in': 0, 'V_you': 0.007217050336327138, 'V_@': 0, 'V_this': 0.006285818034865572, 'V_is': 0.00609986441491963, 'V_on': 0, 'V_=': 0.005237449594855381, 'V_i': 0, "V_'": 0, 'V_)': 0, 'V_(': 0, 'V_Subject': 0.0043926051955734255, 'V_be': 0, 'V_!': 0.004174439137526612, 'V_your': 0, 'V_hou': 0, 'V_that': 0, 'V_enron': 0, 'V_with': 0, 'V_we': 0, 'V_from': 0, 'V_have': 0, 'V_$': 0, 'V_will': 0, 'V_s': 0, 'V_are': 0.003074823636901398, 'V_or': 0, 'V_as': 0, 'V_at': 0, 'V_;': 0.0029562232966209153, 'V_it': 0, 'V_3': 0.0028303019476811435, 'V_not': 0, 'V_2000': 0, 'V_com': 0, 'V__': 0, 'V_if': 0, 'V_by': 0, 'V_please': 0, 'V_``': 0, 'V_1': 0.0022724410878433186, 'V_2': 0, 'V_00': 0, 'V_our': 0.002164090159685841, 'V_me': 0.001978136539739899, 'V_%': 0, 'V_|': 0.001956173513762032, 'V_all': 0.0019224968739293025, 'V_gas': 0, 'V_>': 0, 'V_subject': 0, 'V_#': 0, 'V_can': 0.0017907187180620998, 'V_*': 0, 'V_any': 0.001695545605491342, 'V_deal': 0, 'V_d': 0, 'V_am': 0, 'V_e': 0, 'V_10': 0, 'V_http': 0, 'V_0': 0.0015549822392329925, 'V_000': 0, 'V_no': 0.0014993425734223958, 'V_meter': 0, 'V_pm': 0, 'V_an': 0, 'V_4': 0, 'V_has': 0, 'V_hpl': 0, 'V_cc': 0, 'V_5': 0, 'V_re': 0.001338280382918037, 'V_was': 0, 'V_company': 0, 'V_2001': 0, 'V_new': 0, 'V_t': 0, 'V_may': 0, 'V_thanks': 0, 'V_information': 0, 'V_get': 0, 'V_price': 0, 'V_11': 0, 'V_up': 0, 'V_01': 0, 'V_do': 0, 'V_daren': 0, 'V_corp': 0, 'V_more': 0.0010879018867703517, 'V_here': 0.0010747240711836315, 'V_need': 0, 'V_7': 0.0010586178521331956, 'V_know': 0, 'V_us': 0, 'V_only': 0, 'V_out': 0, 'V_these': 0, 'V_my': 0, 'V_should': 0, 'V_www': 0, 'V_&': 0, 'V_time': 0.0009385533101208552, 'V_there': 0, 'V_email': 0, 'V_12': 0.0009121976789474147, 'V_but': 0, 'V_6': 0, 'V_one': 0, 'V_been': 0, 'V_m': 0, 'V_see': 0.0008565580131368179, 'V_message': 0, 'V_l': 0, 'V_99': 0, 'V_8': 0, 'V_9': 0, 'V_they': 0, 'V_p': 0, 'V_would': 0, 'V_now': 0, 'V_mmbtu': 0, 'V_j': 0, 'V_into': 0, 'V_so': 0, 'V_let': 0, 'V_forwarded': 0, 'V_20': 0, 'V_font': 0, 'V_about': 0, 'V_what': 0, 'V_td': 0, 'V_30': 0, 'V_their': 0, 'V_which': 0.0007233156555377574, 'V_statements': 0, 'V_15': 0, 'V_+': 0, 'V_th': 0, 'V_day': 0, 'V_farmer': 0, 'V_over': 0, 'V_just': 0, 'V_03': 0, 'V_02': 0, 'V_o': 0, 'V_other': 0, 'V_also': 0, 'V_attached': 0, 'V_[': 0, 'V_]': 0, 'V_mail': 0, 'V_its': 0, 'V_x': 0, 'V_b': 0, 'V_nbsp': 0, 'V_like': 0, 'V_c': 0, 'V_xls': 0, 'V_some': 0, 'V_month': 0, 'V_contact': 0, 'V_report': 0, 'V_energy': 0, 'V_free': 0, 'V_sent': 0, 'V_100': 0, 'V_09': 0, 'V_want': 0, 'V_robert': 0, 'V_05': 0.0005505398511785359, 'V_25': 0, 'V_change': 0, 'V_r': 0, 'V_contract': 0, 'V_volume': 0, 'V_when': 0.0005344336321281, 'V_within': 0, 'V_business': 0, 'V_height': 0, 'V_inc': 0, 'V_08': 0, 'V_order': 0.0005139348078820907, 'V_click': 0, 'V_04': 0.0005110064044183751, 'V_who': 0, 'V_nom': 0, 'V_deals': 0, 'V_today': 0, 'V_could': 0, 'V_production': 0, 'V_make': 0, 'V_questions': 0, 'V_he': 0, 'V_call': 0, 'V_back': 0, 'V_them': 0, 'V_sitara': 0, 'V_stock': 0, 'V_number': 0, 'V_go': 0, 'V_use': 0, 'V_texas': 0, 'V_were': 0, 'V_forward': 0, 'V_days': 0, 'V_through': 0, 'V_money': 0, 'V_volumes': 0, 'V_list': 0, 'V_size': 0, 'V_pills': 0.0004553667386077784, 'V_following': 0, 'V_below': 0, 'V_first': 0, 'V_system': 0, 'V_bob': 0, 'V_width': 0, 'V_u': 0, 'V_per': 0, 'V_online': 0.00044365312475291597, 'V_best': 0.0004421889230210582, 'V_don': 0, 'V_2004': 0.00043926051955734253, 'V_how': 0, 'V_take': 0, 'V_investment': 0, 'V_24': 0, 'V_06': 0, 'V_looking': 0, 'V_net': 0, 'V_file': 0, 'V_21': 0, 'V_pec': 0, 'V_flow': 0, 'V_available': 0.000412904888383902, 'V_60': 0, 'V_well': 0, 'V_07': 0, 'V_50': 0, 'V_products' ...
# spam

# %%
# train the classifier using these features
train_set, test_set = TFIDF_featuresets[2700:], TFIDF_featuresets[:2700]
classifier = nltk.NaiveBayesClassifier.train(train_set)
nltk.classify.accuracy(classifier, test_set)
# Out:
# 0.9533333333333334
